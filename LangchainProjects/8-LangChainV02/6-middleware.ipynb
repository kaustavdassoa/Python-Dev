# %% [markdown]
# ### Middleware
#
# Middleware provides a way to more tightly control what happens inside the agent. Middleware is useful for the following:
# - Tracking agent behavior with logging, analytics, and debugging.
# - Transforming prompts, tool selection, and output formatting.
# - Adding retries, fallbacks, and early termination logic.
# - Applying rate limits, guardrails, and PII detection.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### Summarization MiddleWare
# Automatically summarize conversation history when approaching token limits, preserving recent messages while compressing older context. Summarization is useful for the following:
# - Long-running conversations that exceed context windows.
# - Multi-turn dialogues with extensive history.
# - Applications where preserving full conversation context matters.

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.messages import HumanMessage, SystemMessage

### Messagebased summarization
agent=create_agent(
    model="gpt-4o-mini",
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model="gpt-4o-mini",
            trigger=("messages",10),
            keep=("messages",4)
        )
    ]
)

# %%
### Run with thread id
config={"configurable":{"thread_id":"test-1"}}

# %%
# Alternative test data
questions = [
    "What is 2+2?",
    "What is 10*5?",
    "What is 100/4?",
    "What is 15-7?",
    "What is 3*3?",
    "What is 4*4?",
]

for q in questions:
    response=agent.invoke({"messages":[HumanMessage(content=q)]},config)
    print(f"Messages: {response}")
    print(f"Messages: {len(response['messages'])}")
# Out:
# Messages: {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n- User asked basic math questions.\n- Responses provided:\n  - 2 + 2 equals 4.\n  - 10 * 5 equals 50.\n  - 100 divided by 4 equals 25.\n  - The last question was "What is 15-7?" (no response recorded).', additional_kwargs={}, response_metadata={}, id='1372d53a-5eca-40f3-acf1-248355b40c8f'), AIMessage(content='15 - 7 equals 8.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 84, 'total_tokens': 92, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsPSFDuNmPnb0CrdcGWgZWT7vHYem', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e63-d479-76d2-8d00-843bfa4b1a04-0', usage_metadata={'input_tokens': 84, 'output_tokens': 8, 'total_tokens': 92, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 3*3?', additional_kwargs={}, response_metadata={}, id='9a276fec-b6ec-48e3-8cb6-73a1e6636458'), AIMessage(content='3 * 3 equals 9.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 107, 'total_tokens': 115, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPSGzbfnA9Rtqj8UTKn9Rl2gJZtC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e63-d75f-7a13-a306-d2f248d74cc5-0', usage_metadata={'input_tokens': 107, 'output_tokens': 8, 'total_tokens': 115, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 4*4?', additional_kwargs={}, response_metadata={}, id='7d34d6c8-01ad-4190-b256-6cc48f07e882'), AIMessage(content='4 * 4 equals 16.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 127, 'total_tokens': 135, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsPSJU6x2jwcf8WRg1xFBHNIgZwKC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e63-e216-72b1-8c9e-2f43ce09ca95-0', usage_metadata={'input_tokens': 127, 'output_tokens': 8, 'total_tokens': 135, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='073664ab-266a-457f-9273-b1b2c1721fda'), AIMessage(content='2 + 2 equals 4.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 150, 'total_tokens': 158, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPSX2ts71ORnU8HaYM0kRAQM7i89', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-1805-75a2-be15-beca849d4622-0', usage_metadata={'input_tokens': ...
# Messages: 8
# Messages: {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n- User asked basic math questions.\n- Responses provided:\n  - 2 + 2 equals 4.\n  - 10 * 5 equals 50.\n  - 100 divided by 4 equals 25.\n  - The last question was "What is 15-7?" (no response recorded).', additional_kwargs={}, response_metadata={}, id='1372d53a-5eca-40f3-acf1-248355b40c8f'), AIMessage(content='15 - 7 equals 8.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 84, 'total_tokens': 92, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsPSFDuNmPnb0CrdcGWgZWT7vHYem', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e63-d479-76d2-8d00-843bfa4b1a04-0', usage_metadata={'input_tokens': 84, 'output_tokens': 8, 'total_tokens': 92, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 3*3?', additional_kwargs={}, response_metadata={}, id='9a276fec-b6ec-48e3-8cb6-73a1e6636458'), AIMessage(content='3 * 3 equals 9.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 107, 'total_tokens': 115, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPSGzbfnA9Rtqj8UTKn9Rl2gJZtC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e63-d75f-7a13-a306-d2f248d74cc5-0', usage_metadata={'input_tokens': 107, 'output_tokens': 8, 'total_tokens': 115, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 4*4?', additional_kwargs={}, response_metadata={}, id='7d34d6c8-01ad-4190-b256-6cc48f07e882'), AIMessage(content='4 * 4 equals 16.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 127, 'total_tokens': 135, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CsPSJU6x2jwcf8WRg1xFBHNIgZwKC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e63-e216-72b1-8c9e-2f43ce09ca95-0', usage_metadata={'input_tokens': 127, 'output_tokens': 8, 'total_tokens': 135, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 2+2?', additional_kwargs={}, response_metadata={}, id='073664ab-266a-457f-9273-b1b2c1721fda'), AIMessage(content='2 + 2 equals 4.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 150, 'total_tokens': 158, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPSX2ts71ORnU8HaYM0kRAQM7i89', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-1805-75a2-be15-beca849d4622-0', usage_metadata={'input_tokens': ...
# Messages: 10
# Messages: {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n- User asked basic math questions.\n- Responses provided:\n  - 2 + 2 equals 4.\n  - 10 * 5 equals 50.\n  - 100 divided by 4 equals 25.\n  - 15 - 7 equals 8.\n  - 3 * 3 equals 9.\n  - 4 * 4 equals 16.', additional_kwargs={}, response_metadata={}, id='e94afd17-7b4b-4e45-83bc-4d54ef9ab082'), AIMessage(content='2 + 2 equals 4.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 150, 'total_tokens': 158, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPSX2ts71ORnU8HaYM0kRAQM7i89', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-1805-75a2-be15-beca849d4622-0', usage_metadata={'input_tokens': 150, 'output_tokens': 8, 'total_tokens': 158, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 10*5?', additional_kwargs={}, response_metadata={}, id='43f10e79-0124-4e77-83c3-68b31c272550'), AIMessage(content='10 * 5 equals 50.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 173, 'total_tokens': 181, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPSYd4smFqkxKqz9qJT1pZu3jMht', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-1bce-7da3-ba50-ed1cde04fe87-0', usage_metadata={'input_tokens': 173, 'output_tokens': 8, 'total_tokens': 181, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 100/4?', additional_kwargs={}, response_metadata={}, id='3bedb764-9850-466f-b5a4-ef257f4e1eeb'), AIMessage(content='100 divided by 4 equals 25.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 141, 'total_tokens': 150, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_3683ee3deb', 'id': 'chatcmpl-CsPSbK3I10Jux6i53ly3FZIqjynoM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-2877-70f0-bd61-8dd711bee013-0', usage_metadata={'input_tokens': 141, 'output_tokens': 9, 'total_tokens': 150, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Messages: 6
# Messages: {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n- User asked basic math questions.\n- Responses provided:\n  - 2 + 2 equals 4.\n  - 10 * 5 equals 50.\n  - 100 divided by 4 equals 25.\n  - 15 - 7 equals 8.\n  - 3 * 3 equals 9.\n  - 4 * 4 equals 16.', additional_kwargs={}, response_metadata={}, id='e94afd17-7b4b-4e45-83bc-4d54ef9ab082'), AIMessage(content='2 + 2 equals 4.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 150, 'total_tokens': 158, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPSX2ts71ORnU8HaYM0kRAQM7i89', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-1805-75a2-be15-beca849d4622-0', usage_metadata={'input_tokens': 150, 'output_tokens': 8, 'total_tokens': 158, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 10*5?', additional_kwargs={}, response_metadata={}, id='43f10e79-0124-4e77-83c3-68b31c272550'), AIMessage(content='10 * 5 equals 50.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 173, 'total_tokens': 181, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPSYd4smFqkxKqz9qJT1pZu3jMht', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-1bce-7da3-ba50-ed1cde04fe87-0', usage_metadata={'input_tokens': 173, 'output_tokens': 8, 'total_tokens': 181, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 100/4?', additional_kwargs={}, response_metadata={}, id='3bedb764-9850-466f-b5a4-ef257f4e1eeb'), AIMessage(content='100 divided by 4 equals 25.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 141, 'total_tokens': 150, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_3683ee3deb', 'id': 'chatcmpl-CsPSbK3I10Jux6i53ly3FZIqjynoM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-2877-70f0-bd61-8dd711bee013-0', usage_metadata={'input_tokens': 141, 'output_tokens': 9, 'total_tokens': 150, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 15-7?', additional_kwargs={}, response_metadata={}, id='e91d071b-29eb-4379-bc68-2d227efd3649'), AIMessage(content='15 - 7 equals 8.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 165, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_3683ee3deb', 'id': 'chatcmpl-CsPScsR4drrEJ4F1QG0YkXl9j0yWQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-2afa-7152-8303-ec16a0bae2a6-0', usage_metada ...
# Messages: 8
# Messages: {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n- User asked basic math questions.\n- Responses provided:\n  - 2 + 2 equals 4.\n  - 10 * 5 equals 50.\n  - 100 divided by 4 equals 25.\n  - 15 - 7 equals 8.\n  - 3 * 3 equals 9.\n  - 4 * 4 equals 16.', additional_kwargs={}, response_metadata={}, id='e94afd17-7b4b-4e45-83bc-4d54ef9ab082'), AIMessage(content='2 + 2 equals 4.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 150, 'total_tokens': 158, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPSX2ts71ORnU8HaYM0kRAQM7i89', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-1805-75a2-be15-beca849d4622-0', usage_metadata={'input_tokens': 150, 'output_tokens': 8, 'total_tokens': 158, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 10*5?', additional_kwargs={}, response_metadata={}, id='43f10e79-0124-4e77-83c3-68b31c272550'), AIMessage(content='10 * 5 equals 50.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 173, 'total_tokens': 181, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPSYd4smFqkxKqz9qJT1pZu3jMht', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-1bce-7da3-ba50-ed1cde04fe87-0', usage_metadata={'input_tokens': 173, 'output_tokens': 8, 'total_tokens': 181, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 100/4?', additional_kwargs={}, response_metadata={}, id='3bedb764-9850-466f-b5a4-ef257f4e1eeb'), AIMessage(content='100 divided by 4 equals 25.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 141, 'total_tokens': 150, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_3683ee3deb', 'id': 'chatcmpl-CsPSbK3I10Jux6i53ly3FZIqjynoM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-2877-70f0-bd61-8dd711bee013-0', usage_metadata={'input_tokens': 141, 'output_tokens': 9, 'total_tokens': 150, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 15-7?', additional_kwargs={}, response_metadata={}, id='e91d071b-29eb-4379-bc68-2d227efd3649'), AIMessage(content='15 - 7 equals 8.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 165, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_3683ee3deb', 'id': 'chatcmpl-CsPScsR4drrEJ4F1QG0YkXl9j0yWQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-2afa-7152-8303-ec16a0bae2a6-0', usage_metada ...
# Messages: 10
# Messages: {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n- User asked basic math questions.\n- Responses provided:\n  - 2 + 2 equals 4.\n  - 10 * 5 equals 50.\n  - 100 divided by 4 equals 25.\n  - 15 - 7 equals 8.', additional_kwargs={}, response_metadata={}, id='c0829d1a-364d-450a-bf83-d0cc0cbaf642'), AIMessage(content='15 - 7 equals 8.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 165, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_3683ee3deb', 'id': 'chatcmpl-CsPScsR4drrEJ4F1QG0YkXl9j0yWQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-2afa-7152-8303-ec16a0bae2a6-0', usage_metadata={'input_tokens': 165, 'output_tokens': 8, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 3*3?', additional_kwargs={}, response_metadata={}, id='83555e99-f343-4c32-ac87-a96bdae6c010'), AIMessage(content='3 * 3 equals 9.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 188, 'total_tokens': 196, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_3683ee3deb', 'id': 'chatcmpl-CsPSdFDF9mopY7ttveM5Z1sTS4KjK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-2ec8-70a1-92fe-b0ba200bc712-0', usage_metadata={'input_tokens': 188, 'output_tokens': 8, 'total_tokens': 196, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='What is 4*4?', additional_kwargs={}, response_metadata={}, id='421e4896-421c-4b4a-a7de-07af5b2a7efb'), AIMessage(content='4 * 4 equals 16.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 119, 'total_tokens': 127, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_3683ee3deb', 'id': 'chatcmpl-CsPSfgpz6ghiY7ndfcLoYa1yYFDF8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e64-3973-79a0-9748-15c3a6dd72cb-0', usage_metadata={'input_tokens': 119, 'output_tokens': 8, 'total_tokens': 127, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# Messages: 6

# %% [markdown]
# ## token Size

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import InMemorySaver

@tool
def search_hotels(city: str) -> str:
    """Search hotels - returns long response to use more tokens."""
    return f"""Hotels in {city}:
    1. Grand Hotel - 5 star, $350/night, spa, pool, gym
    2. City Inn - 4 star, $180/night, business center
    3. Budget Stay - 3 star, $75/night, free wifi"""


agent=create_agent(
    model="gpt-4o-mini",
    tools=[search_hotels],
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model="gpt-4o-mini",
            trigger=("tokens",550),
            keep=("tokens",200),
        ),
    ]
)

config = {"configurable": {"thread_id": "test-1"}}

# Token counter (approximate)
def count_tokens(messages):
    total_chars = sum(len(str(m.content)) for m in messages)
    return total_chars // 4  # 4 chars ≈ 1 token

# %%
# Run test
cities = ["Paris", "London", "Tokyo", "New York", "Dubai", "Singapore"]

for city in cities:
    response = agent.invoke(
        {"messages": [HumanMessage(content=f"Find hotels in {city}")]},
        config=config
    )
    
    tokens = count_tokens(response["messages"])
    print(f"{city}: ~{tokens} tokens, {len(response['messages'])} messages")
    print(f"{(response['messages'])}")
# Out:
# Paris: ~123 tokens, 4 messages
# [HumanMessage(content='Find hotels in Paris', additional_kwargs={}, response_metadata={}, id='b7d5f7e8-4ea8-4178-a619-d3f793776737'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 53, 'total_tokens': 68, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPThCJsaQLWr1EJIHZZLQO68lhMI', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b6e65-30ab-7c31-9bc9-bfa23fe4c4ac-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_BGGHwfvuP74cO4ZM7QsRGRfg', 'type': 'tool_call'}], usage_metadata={'input_tokens': 53, 'output_tokens': 15, 'total_tokens': 68, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='aebf6738-9fe1-4c6e-aa9d-c9e473bf59c0', tool_call_id='call_BGGHwfvuP74cO4ZM7QsRGRfg'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - 5 stars, $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn** - 4 stars, $180/night\n   - Amenities: Business center\n\n3. **Budget Stay** - 3 stars, $75/night\n   - Amenities: Free wifi\n\nLet me know if you need more information or assistance!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 137, 'total_tokens': 225, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPTiMEJuFyN2U8UCf5KYeRfKUcnl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e65-36e9-7f72-9f86-da2d0e022e63-0', usage_metadata={'input_tokens': 137, 'output_tokens': 88, 'total_tokens': 225, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# London: ~249 tokens, 8 messages
# [HumanMessage(content='Find hotels in Paris', additional_kwargs={}, response_metadata={}, id='b7d5f7e8-4ea8-4178-a619-d3f793776737'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 53, 'total_tokens': 68, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPThCJsaQLWr1EJIHZZLQO68lhMI', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b6e65-30ab-7c31-9bc9-bfa23fe4c4ac-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_BGGHwfvuP74cO4ZM7QsRGRfg', 'type': 'tool_call'}], usage_metadata={'input_tokens': 53, 'output_tokens': 15, 'total_tokens': 68, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='aebf6738-9fe1-4c6e-aa9d-c9e473bf59c0', tool_call_id='call_BGGHwfvuP74cO4ZM7QsRGRfg'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - 5 stars, $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn** - 4 stars, $180/night\n   - Amenities: Business center\n\n3. **Budget Stay** - 3 stars, $75/night\n   - Amenities: Free wifi\n\nLet me know if you need more information or assistance!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 137, 'total_tokens': 225, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPTiMEJuFyN2U8UCf5KYeRfKUcnl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e65-36e9-7f72-9f86-da2d0e022e63-0', usage_metadata={'input_tokens': 137, 'output_tokens': 88, 'total_tokens': 225, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Find hotels in London', additional_kwargs={}, response_metadata={}, id='686feae2-f41e-411d-89d6-73e96178a89b'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 236, 'total_tokens': 251, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPTkJIWMQVj80BQPRdCbwo7KNWZ7', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b6e65-3ef5-7990-a564-363fbccc3cec-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_8nvXu0RAJfJukDm3qKrana4f', 'type': 'tool_call'}], usage_metadata={'input_tokens': 236, 'output_tokens': 15, 'total_tokens': 251, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='7e4a9b21-44ae-419f-b3ff-bd535c79b226', tool_call_id='call_8nvXu0RAJfJukDm3qKrana4f'), AIMessage(content='He ...
# Tokyo: ~376 tokens, 12 messages
# [HumanMessage(content='Find hotels in Paris', additional_kwargs={}, response_metadata={}, id='b7d5f7e8-4ea8-4178-a619-d3f793776737'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 53, 'total_tokens': 68, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPThCJsaQLWr1EJIHZZLQO68lhMI', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b6e65-30ab-7c31-9bc9-bfa23fe4c4ac-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_BGGHwfvuP74cO4ZM7QsRGRfg', 'type': 'tool_call'}], usage_metadata={'input_tokens': 53, 'output_tokens': 15, 'total_tokens': 68, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='aebf6738-9fe1-4c6e-aa9d-c9e473bf59c0', tool_call_id='call_BGGHwfvuP74cO4ZM7QsRGRfg'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - 5 stars, $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn** - 4 stars, $180/night\n   - Amenities: Business center\n\n3. **Budget Stay** - 3 stars, $75/night\n   - Amenities: Free wifi\n\nLet me know if you need more information or assistance!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 137, 'total_tokens': 225, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPTiMEJuFyN2U8UCf5KYeRfKUcnl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e65-36e9-7f72-9f86-da2d0e022e63-0', usage_metadata={'input_tokens': 137, 'output_tokens': 88, 'total_tokens': 225, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Find hotels in London', additional_kwargs={}, response_metadata={}, id='686feae2-f41e-411d-89d6-73e96178a89b'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 236, 'total_tokens': 251, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPTkJIWMQVj80BQPRdCbwo7KNWZ7', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b6e65-3ef5-7990-a564-363fbccc3cec-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_8nvXu0RAJfJukDm3qKrana4f', 'type': 'tool_call'}], usage_metadata={'input_tokens': 236, 'output_tokens': 15, 'total_tokens': 251, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='7e4a9b21-44ae-419f-b3ff-bd535c79b226', tool_call_id='call_8nvXu0RAJfJukDm3qKrana4f'), AIMessage(content='He ...
# New York: ~431 tokens, 9 messages
# [HumanMessage(content='Here is a summary of the conversation to date:\n\nUser requested hotel information for Paris and London. The AI provided lists of hotels in both cities, detailing star ratings, prices, and amenities:\n\n**Hotels in Paris:**\n1. **Grand Hotel** - 5 stars, $350/night; Amenities: Spa, pool, gym\n2. **City Inn** - 4 stars, $180/night; Amenities: Business center\n3. **Budget Stay** - 3 stars, $75/night; Amenities: Free wifi\n\n**Hotels in London:**\n1. **Grand Hotel** - 5 stars, $350/night; Amenities: Spa, pool, gym\n2. **City Inn** - 4 stars, $180/night; Amenities: Business center\n3. **Budget Stay** - 3 stars, $75/night; Amenities: Free wifi\n\nThe AI offered further assistance if needed.', additional_kwargs={}, response_metadata={}, id='35266ad8-f95d-4189-85ff-5ba4b08b7b00'), HumanMessage(content='Find hotels in Tokyo', additional_kwargs={}, response_metadata={}, id='28d99db2-899f-4efa-8ced-10a1fb986927'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 421, 'total_tokens': 436, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPTn4wWhRUa1bkXZaZ8KrDdEBXz6', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b6e65-4a4c-70c3-9e70-613eaf697103-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Tokyo'}, 'id': 'call_qTryjdB71dv2fROZSbC5dqAB', 'type': 'tool_call'}], usage_metadata={'input_tokens': 421, 'output_tokens': 15, 'total_tokens': 436, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Tokyo:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='33d25dab-4972-4ec9-acaa-3e0709349d31', tool_call_id='call_qTryjdB71dv2fROZSbC5dqAB'), AIMessage(content='Here are some hotels in Tokyo:\n\n1. **Grand Hotel** - 5 stars, $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn** - 4 stars, $180/night\n   - Amenities: Business center\n\n3. **Budget Stay** - 3 stars, $75/night\n   - Amenities: Free wifi\n\nLet me know if you need more information or help with anything else!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 91, 'prompt_tokens': 505, 'total_tokens': 596, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPToY4KuECRBWs8BZlZX0y8c2CWk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e65-4e84-73f2-8070-a98626b2814a-0', usage_metadata={'input_tokens': 505, 'output_tokens': 91, 'total_tokens': 596, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Find hotels in New York', additional_kwargs={}, response_metadata={}, id='1634298e-0a3e-479f-bb4e-15450f90bbc0'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 428, 'total_tokens': 444, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id':  ...
# Dubai: ~482 tokens, 8 messages
# [HumanMessage(content='Here is a summary of the conversation to date:\n\nUser requested hotel information for Paris, London, Tokyo, and New York. The AI provided lists of hotels for each city, detailing star ratings, prices, and amenities:\n\n**Hotels in Paris:**\n1. **Grand Hotel** - 5 stars, $350/night; Amenities: Spa, pool, gym\n2. **City Inn** - 4 stars, $180/night; Amenities: Business center\n3. **Budget Stay** - 3 stars, $75/night; Amenities: Free wifi\n\n**Hotels in London:**\n1. **Grand Hotel** - 5 stars, $350/night; Amenities: Spa, pool, gym\n2. **City Inn** - 4 stars, $180/night; Amenities: Business center\n3. **Budget Stay** - 3 stars, $75/night; Amenities: Free wifi\n\n**Hotels in Tokyo:**\n1. **Grand Hotel** - 5 stars, $350/night; Amenities: Spa, pool, gym\n2. **City Inn** - 4 stars, $180/night; Amenities: Business center\n3. **Budget Stay** - 3 stars, $75/night; Amenities: Free wifi\n\nThe AI offered further assistance if needed.', additional_kwargs={}, response_metadata={}, id='541db13f-ec56-436f-a015-ea1638d8f7c4'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 428, 'total_tokens': 444, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPTv8BZ40pHKOBP1gJTEEe34gLJk', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b6e65-6a62-7cc0-af9d-aa3fa47383b2-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'New York'}, 'id': 'call_5SW03IGi18mNKkTV1nK2Q8Bh', 'type': 'tool_call'}], usage_metadata={'input_tokens': 428, 'output_tokens': 16, 'total_tokens': 444, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in New York:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='f643a05d-2f41-4ee8-869f-27a2292d6bb1', tool_call_id='call_5SW03IGi18mNKkTV1nK2Q8Bh'), AIMessage(content='Here are some hotels in New York:\n\n1. **Grand Hotel** - 5 stars, $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn** - 4 stars, $180/night\n   - Amenities: Business center\n\n3. **Budget Stay** - 3 stars, $75/night\n   - Amenities: Free wifi\n\nIf you have any further questions or need assistance with something else, feel free to ask!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 96, 'prompt_tokens': 514, 'total_tokens': 610, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPTxyRsumivbtbL0xJdY5atoxaUF', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e65-7021-74b2-b0ee-81ee97beb3e5-0', usage_metadata={'input_tokens': 514, 'output_tokens': 96, 'total_tokens': 610, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Find hotels in Dubai', additional_kwargs={}, response_metadata={}, id='bb8bf20e-d9f1-43d8-9a4c-26b3d7c0114f'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 501, 'total_tokens': 516, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, ...
# Singapore: ~528 tokens, 6 messages
# [HumanMessage(content='Here is a summary of the conversation to date:\n\nUser requested hotel information for Paris, London, Tokyo, New York, and Dubai. The AI provided lists of hotels for each city, detailing star ratings, prices, and amenities:\n\n**Hotels in Paris:**\n1. Grand Hotel - 5 stars, $350/night; Amenities: Spa, pool, gym\n2. City Inn - 4 stars, $180/night; Amenities: Business center\n3. Budget Stay - 3 stars, $75/night; Amenities: Free wifi\n\n**Hotels in London:**\n1. Grand Hotel - 5 stars, $350/night; Amenities: Spa, pool, gym\n2. City Inn - 4 stars, $180/night; Amenities: Business center\n3. Budget Stay - 3 stars, $75/night; Amenities: Free wifi\n\n**Hotels in Tokyo:**\n1. Grand Hotel - 5 stars, $350/night; Amenities: Spa, pool, gym\n2. City Inn - 4 stars, $180/night; Amenities: Business center\n3. Budget Stay - 3 stars, $75/night; Amenities: Free wifi\n\n**Hotels in New York:**\n1. Grand Hotel - 5 stars, $350/night; Amenities: Spa, pool, gym\n2. City Inn - 4 stars, $180/night; Amenities: Business center\n3. Budget Stay - 3 stars, $75/night; Amenities: Free wifi\n\n**Hotels in Dubai:**\n1. Grand Hotel - 5 star, $350/night; Amenities: spa, pool, gym\n2. City Inn - 4 star, $180/night; Amenities: business center\n3. Budget Stay - 3 star, $75/night; Amenities: free wifi\n\nThe AI offered further assistance if needed.', additional_kwargs={}, response_metadata={}, id='6908aba0-d91f-49c5-a3c7-84ca1e559788'), AIMessage(content='Here are some hotels in Dubai:\n\n1. **Grand Hotel** - 5 stars, $350/night\n   - Amenities: Spa, pool, gym\n\n2. **City Inn** - 4 stars, $180/night\n   - Amenities: Business center\n\n3. **Budget Stay** - 3 stars, $75/night\n   - Amenities: Free wifi\n\nIf you need more information or assistance, just let me know!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 90, 'prompt_tokens': 585, 'total_tokens': 675, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPU6QoN3Ddvg2nAmM0EwNKtTOLGu', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b6e65-9582-7980-8bb2-73d03d8b79ae-0', usage_metadata={'input_tokens': 585, 'output_tokens': 90, 'total_tokens': 675, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Find hotels in Singapore', additional_kwargs={}, response_metadata={}, id='27e73cd1-f323-4f12-b09b-9e59d281ce42'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 571, 'total_tokens': 586, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-CsPUGPxtb0LUa76p4AsCJvQY7TnnO', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b6e65-ba5f-7be0-b6a3-23180b75db23-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Singapore'}, 'id': 'call_qNVqDShVZe59jpQv3il1g5Un', 'type': 'tool_call'}], usage_metadata={'input_tokens': 571, 'output_tokens': 15, 'total_tokens': 586, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Singapore:\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $180/night, business center\n    3. Budget Stay - 3 star, $75/night, free wifi', name='search_hotels', id='b553e001-8d33-4b10-9f63-3247349da438', tool_call_id='call_qNVqDSh ...

# %% [markdown]
# ### Fraction

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import InMemorySaver

@tool
def search_hotels(city: str) -> str:
    """Search hotels."""
    return f"Hotels in {city}: Grand Hotel $350, City Inn $180, Budget Stay $75"

# LOW fraction for testing!
agent = create_agent(
    model="gpt-4o-mini",
    tools=[search_hotels],
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model="gpt-4o-mini",
            trigger=("fraction", 0.005),  # 0.5% = ~640 tokens
            keep=("fraction", 0.002),     # 0.2% = ~256 tokens
        ),
    ],
)

config = {"configurable": {"thread_id": "test-1"}}

# Token counter
def count_tokens(messages):
    return sum(len(str(m.content)) for m in messages) // 4

# Test
cities = ["Paris", "London", "Tokyo", "New York", "Dubai", "Singapore"]

for city in cities:
    response = agent.invoke(
        {"messages": [HumanMessage(content=f"Hotels in {city}")]},
        config=config
    )
    tokens = count_tokens(response["messages"])
    fraction = tokens / 128000  # gpt-4o-mini context
    print(f"{city}: ~{tokens} tokens ({fraction:.4%}), {len(response['messages'])} msgs")
    print(response['messages'])
# Out:
# Paris: ~64 tokens (0.0500%), 4 msgs
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='a83cc0a1-77b5-4ab3-bd76-e13156000b53'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 44, 'total_tokens': 59, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-Co3ArOQrPc3zwg995EChBheLKW5dE', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--87bc14f2-8864-4945-986c-9e54ca9eb0c3-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_n5G4wPITTn9Qbn7PcmixQe95', 'type': 'tool_call'}], usage_metadata={'input_tokens': 44, 'output_tokens': 15, 'total_tokens': 59, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='feb821aa-f8f1-4541-8ade-8a97f57021c4', tool_call_id='call_n5G4wPITTn9Qbn7PcmixQe95'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nLet me know if you need more information!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 86, 'total_tokens': 139, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-Co3AsPmXAME1wnw7emhYqXd2IthxK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--a7b6cf3f-75e1-49cf-9af8-68fd8167175f-0', usage_metadata={'input_tokens': 86, 'output_tokens': 53, 'total_tokens': 139, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
# London: ~133 tokens (0.1039%), 8 msgs
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='a83cc0a1-77b5-4ab3-bd76-e13156000b53'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 44, 'total_tokens': 59, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-Co3ArOQrPc3zwg995EChBheLKW5dE', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--87bc14f2-8864-4945-986c-9e54ca9eb0c3-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_n5G4wPITTn9Qbn7PcmixQe95', 'type': 'tool_call'}], usage_metadata={'input_tokens': 44, 'output_tokens': 15, 'total_tokens': 59, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='feb821aa-f8f1-4541-8ade-8a97f57021c4', tool_call_id='call_n5G4wPITTn9Qbn7PcmixQe95'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nLet me know if you need more information!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 86, 'total_tokens': 139, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-Co3AsPmXAME1wnw7emhYqXd2IthxK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--a7b6cf3f-75e1-49cf-9af8-68fd8167175f-0', usage_metadata={'input_tokens': 86, 'output_tokens': 53, 'total_tokens': 139, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in London', additional_kwargs={}, response_metadata={}, id='8f949465-9a4c-48f0-8679-e4bafd8a9d6c'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 149, 'total_tokens': 164, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_644f11dd4d', 'id': 'chatcmpl-Co3Atj79Bk1fFmBedUtosTwJz3Z1Y', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--6848c8d8-2f6f-4924-bc59-94055caabbba-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_GWs0LaQbkZ7Iypm02WGk8ZQy', 'type': 'tool_call'}], usage_metadata={'input_tokens': 149, 'output_tokens': 15, 'total_tokens': 164, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='252bdd69-1ccf-4585-9cf4-13a8ae7593e5', tool_call_id='call_GWs0LaQbkZ7Iypm02WGk8ZQy'), AIMessage(content='Here are some hotels in London:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nIf you need more details or assistance, feel free to ask!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 191, 'total_tokens': 248, 'completion_tokens_deta ...
# Tokyo: ~203 tokens (0.1586%), 12 msgs
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='a83cc0a1-77b5-4ab3-bd76-e13156000b53'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 44, 'total_tokens': 59, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-Co3ArOQrPc3zwg995EChBheLKW5dE', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--87bc14f2-8864-4945-986c-9e54ca9eb0c3-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_n5G4wPITTn9Qbn7PcmixQe95', 'type': 'tool_call'}], usage_metadata={'input_tokens': 44, 'output_tokens': 15, 'total_tokens': 59, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='feb821aa-f8f1-4541-8ade-8a97f57021c4', tool_call_id='call_n5G4wPITTn9Qbn7PcmixQe95'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nLet me know if you need more information!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 86, 'total_tokens': 139, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-Co3AsPmXAME1wnw7emhYqXd2IthxK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--a7b6cf3f-75e1-49cf-9af8-68fd8167175f-0', usage_metadata={'input_tokens': 86, 'output_tokens': 53, 'total_tokens': 139, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in London', additional_kwargs={}, response_metadata={}, id='8f949465-9a4c-48f0-8679-e4bafd8a9d6c'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 149, 'total_tokens': 164, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_644f11dd4d', 'id': 'chatcmpl-Co3Atj79Bk1fFmBedUtosTwJz3Z1Y', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--6848c8d8-2f6f-4924-bc59-94055caabbba-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_GWs0LaQbkZ7Iypm02WGk8ZQy', 'type': 'tool_call'}], usage_metadata={'input_tokens': 149, 'output_tokens': 15, 'total_tokens': 164, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='252bdd69-1ccf-4585-9cf4-13a8ae7593e5', tool_call_id='call_GWs0LaQbkZ7Iypm02WGk8ZQy'), AIMessage(content='Here are some hotels in London:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nIf you need more details or assistance, feel free to ask!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 191, 'total_tokens': 248, 'completion_tokens_deta ...
# New York: ~276 tokens (0.2156%), 16 msgs
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='a83cc0a1-77b5-4ab3-bd76-e13156000b53'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 44, 'total_tokens': 59, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-Co3ArOQrPc3zwg995EChBheLKW5dE', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--87bc14f2-8864-4945-986c-9e54ca9eb0c3-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_n5G4wPITTn9Qbn7PcmixQe95', 'type': 'tool_call'}], usage_metadata={'input_tokens': 44, 'output_tokens': 15, 'total_tokens': 59, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='feb821aa-f8f1-4541-8ade-8a97f57021c4', tool_call_id='call_n5G4wPITTn9Qbn7PcmixQe95'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nLet me know if you need more information!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 86, 'total_tokens': 139, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-Co3AsPmXAME1wnw7emhYqXd2IthxK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--a7b6cf3f-75e1-49cf-9af8-68fd8167175f-0', usage_metadata={'input_tokens': 86, 'output_tokens': 53, 'total_tokens': 139, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in London', additional_kwargs={}, response_metadata={}, id='8f949465-9a4c-48f0-8679-e4bafd8a9d6c'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 149, 'total_tokens': 164, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_644f11dd4d', 'id': 'chatcmpl-Co3Atj79Bk1fFmBedUtosTwJz3Z1Y', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--6848c8d8-2f6f-4924-bc59-94055caabbba-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_GWs0LaQbkZ7Iypm02WGk8ZQy', 'type': 'tool_call'}], usage_metadata={'input_tokens': 149, 'output_tokens': 15, 'total_tokens': 164, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='252bdd69-1ccf-4585-9cf4-13a8ae7593e5', tool_call_id='call_GWs0LaQbkZ7Iypm02WGk8ZQy'), AIMessage(content='Here are some hotels in London:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nIf you need more details or assistance, feel free to ask!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 191, 'total_tokens': 248, 'completion_tokens_deta ...
# Dubai: ~349 tokens (0.2727%), 20 msgs
# [HumanMessage(content='Hotels in Paris', additional_kwargs={}, response_metadata={}, id='a83cc0a1-77b5-4ab3-bd76-e13156000b53'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 44, 'total_tokens': 59, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-Co3ArOQrPc3zwg995EChBheLKW5dE', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--87bc14f2-8864-4945-986c-9e54ca9eb0c3-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'call_n5G4wPITTn9Qbn7PcmixQe95', 'type': 'tool_call'}], usage_metadata={'input_tokens': 44, 'output_tokens': 15, 'total_tokens': 59, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in Paris: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='feb821aa-f8f1-4541-8ade-8a97f57021c4', tool_call_id='call_n5G4wPITTn9Qbn7PcmixQe95'), AIMessage(content='Here are some hotels in Paris:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nLet me know if you need more information!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 86, 'total_tokens': 139, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-Co3AsPmXAME1wnw7emhYqXd2IthxK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--a7b6cf3f-75e1-49cf-9af8-68fd8167175f-0', usage_metadata={'input_tokens': 86, 'output_tokens': 53, 'total_tokens': 139, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in London', additional_kwargs={}, response_metadata={}, id='8f949465-9a4c-48f0-8679-e4bafd8a9d6c'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 149, 'total_tokens': 164, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_644f11dd4d', 'id': 'chatcmpl-Co3Atj79Bk1fFmBedUtosTwJz3Z1Y', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--6848c8d8-2f6f-4924-bc59-94055caabbba-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'call_GWs0LaQbkZ7Iypm02WGk8ZQy', 'type': 'tool_call'}], usage_metadata={'input_tokens': 149, 'output_tokens': 15, 'total_tokens': 164, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in London: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='252bdd69-1ccf-4585-9cf4-13a8ae7593e5', tool_call_id='call_GWs0LaQbkZ7Iypm02WGk8ZQy'), AIMessage(content='Here are some hotels in London:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nIf you need more details or assistance, feel free to ask!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 191, 'total_tokens': 248, 'completion_tokens_deta ...
# Singapore: ~365 tokens (0.2852%), 12 msgs
# [HumanMessage(content='Here is a summary of the conversation to date:\n\n1. User requested information about hotels in multiple cities: \n   - Paris \n   - London \n   - Tokyo \n   - New York\n\n2. For each city, a search tool provided a list of hotels along with their prices:\n   - **Paris**: \n     - Grand Hotel - $350 per night\n     - City Inn - $180 per night\n     - Budget Stay - $75 per night\n   - **London**: \n     - Grand Hotel - $350 per night\n     - City Inn - $180 per night\n     - Budget Stay - $75 per night\n   - **Tokyo**: \n     - Grand Hotel - $350 per night\n     - City Inn - $180 per night\n     - Budget Stay - $75 per night', additional_kwargs={}, response_metadata={}, id='b291e56c-65b7-41f5-8fd5-e9a3a0a53ba2'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 367, 'total_tokens': 383, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8bbc38b4db', 'id': 'chatcmpl-Co3B0Gw0dphE7SM0v15VI2EgpmWqp', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--026633c2-3d66-45fc-84db-05c4265d5830-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'New York'}, 'id': 'call_RCg8uWCt2cH07d8FejQIY0HU', 'type': 'tool_call'}], usage_metadata={'input_tokens': 367, 'output_tokens': 16, 'total_tokens': 383, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Hotels in New York: Grand Hotel $350, City Inn $180, Budget Stay $75', name='search_hotels', id='eac8c9b8-190c-4cb8-a32b-934f5c63a973', tool_call_id='call_RCg8uWCt2cH07d8FejQIY0HU'), AIMessage(content='Here are some hotels in New York:\n\n1. **Grand Hotel** - $350 per night\n2. **City Inn** - $180 per night\n3. **Budget Stay** - $75 per night\n\nIf you need further assistance or more options, just let me know!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 59, 'prompt_tokens': 411, 'total_tokens': 470, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_8bbc38b4db', 'id': 'chatcmpl-Co3B1MVHF5MeGnr772D7Yj3CRpAax', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--5e912612-adb1-4d92-8e8f-23f9bfce5fac-0', usage_metadata={'input_tokens': 411, 'output_tokens': 59, 'total_tokens': 470, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='Hotels in Dubai', additional_kwargs={}, response_metadata={}, id='6ab6deea-52ca-4a90-b602-8959e58e00ac'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 480, 'total_tokens': 495, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_c4585b5b9c', 'id': 'chatcmpl-Co3B3axIVtmIaLG19ZeaueH820SXN', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--0ac8ded0-1a6e-4f47-85b9-613f363d8621-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Dubai'}, 'id': 'call_q6p8yv0hEDkbUwAHLlS5emHZ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 480, 'output_tokens': 15, 'total_tokens': 495, 'input_token_details': {'audio': 0, 'cache_rea ...

# %% [markdown]
# ### Human In the Loop MiddleWare

# %% [markdown]
# Pause agent execution for human approval, editing, or rejection of tool calls before they execute. Human-in-the-loop is useful for the following:
# - High-stakes operations requiring human approval (e.g. database writes, financial transactions).
# - Compliance workflows where human oversight is mandatory.
# - Long-running conversations where human feedback guides the agent.

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langgraph.checkpoint.memory import InMemorySaver

def read_email_tool(email_id: str) -> str:
    """Mock function to read an email by its ID."""
    return f"Email content for ID: {email_id}"

def send_email_tool(recipient: str, subject: str, body: str) -> str:
    """Mock function to send an email."""
    return f"Email sent to {recipient} with subject '{subject}'"

# %%
agent=create_agent(
    model="gpt-4o",
    tools=[read_email_tool,send_email_tool],
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_email_tool":{
                    "allowed_decisions":["approve","edit","reject"]
                },
                "read_email_tool":False,

            }
        )
    ]
)

# %%
config = {"configurable": {"thread_id": "test-approve"}}
# Step 1: Request
result = agent.invoke(
    {"messages": [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'")]},
    config=config
)

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'", additional_kwargs={}, response_metadata={}, id='df7c94ec-7c97-4b68-a7ef-4a1eb4b8ab5e'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 97, 'total_tokens': 125, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ff5f7093b3', 'id': 'chatcmpl-Co4Dem4tAOCx3wFsy4EMA623LU7ZP', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--7b23a6a7-07d9-4ad2-9724-359f1568186a-0', tool_calls=[{'name': 'send_email_tool', 'args': {'recipient': 'john@test.com', 'subject': 'Hello', 'body': 'How are you?'}, 'id': 'call_A8s4sBnakCq3LfGKISYrcQ7u', 'type': 'tool_call'}], usage_metadata={'input_tokens': 97, 'output_tokens': 28, 'total_tokens': 125, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'send_email_tool', 'args': {'recipient': 'john@test.com', 'subject': 'Hello', 'body': 'How are you?'}, 'description': "Tool execution requires approval\n\nTool: send_email_tool\nArgs: {'recipient': 'john@test.com', 'subject': 'Hello', 'body': 'How are you?'}"}], 'review_configs': [{'action_name': 'send_email_tool', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='e7f5e4e99613d6cfded08e269d4ff89f')]}

# %%
from langgraph.types import Command
# Step 2: Approve
if "__interrupt__" in result:
    print("⏸️ Paused! Approving...")
    
    result = agent.invoke(
        Command(
            resume={
                "decisions": [
                    {"type": "approve"}
                ]
            }
        ),
        config=config
    )
    
    print(f"✅ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Approving...
# ✅ Result: The email has been sent to john@test.com with the subject "Hello".

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'", additional_kwargs={}, response_metadata={}, id='df7c94ec-7c97-4b68-a7ef-4a1eb4b8ab5e'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 97, 'total_tokens': 125, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ff5f7093b3', 'id': 'chatcmpl-Co4Dem4tAOCx3wFsy4EMA623LU7ZP', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--7b23a6a7-07d9-4ad2-9724-359f1568186a-0', tool_calls=[{'name': 'send_email_tool', 'args': {'recipient': 'john@test.com', 'subject': 'Hello', 'body': 'How are you?'}, 'id': 'call_A8s4sBnakCq3LfGKISYrcQ7u', 'type': 'tool_call'}], usage_metadata={'input_tokens': 97, 'output_tokens': 28, 'total_tokens': 125, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="Email sent to john@test.com with subject 'Hello'", name='send_email_tool', id='6526d494-341f-4cfb-ba59-c966592ab98d', tool_call_id='call_A8s4sBnakCq3LfGKISYrcQ7u'),
#   AIMessage(content='The email has been sent to john@test.com with the subject "Hello".', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 145, 'total_tokens': 161, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ff5f7093b3', 'id': 'chatcmpl-Co4G0sjzRgH1gDJ5lM2vSKBpGLEAa', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--b77b0cdc-825a-478f-a32d-657addd3f750-0', usage_metadata={'input_tokens': 145, 'output_tokens': 16, 'total_tokens': 161, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ### Reject

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langgraph.checkpoint.memory import InMemorySaver


def read_email_tool(email_id: str) -> str:
    """Mock function to read an email by its ID."""
    return f"Email content for ID: {email_id}"

def send_email_tool(recipient: str, subject: str, body: str) -> str:
    """Mock function to send an email."""
    return f"Email sent to {recipient} with subject '{subject}'"

agent = create_agent(
    model="gpt-4o",
    tools=[read_email_tool,send_email_tool],
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_email_tool": {
                    "allowed_decisions": ["approve", "edit", "reject"],
                },
                "read_email_tool": False,
            }
        ),
    ],
)

# %%
config = {"configurable": {"thread_id": "test-reject"}}
# Step 1: Request
result = agent.invoke(
    {"messages": [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'")]},
    config=config)

# %%
# Step 2: Reject
if "__interrupt__" in result:
    print("⏸️ Paused! Approving...")
    
    result = agent.invoke(
        Command(
            resume={
                "decisions": [
                    {"type": "reject"}
                ]
            }
        ),
        config=config
    )
    
    print(f"✅ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Approving...
# ✅ Result: It seems there was an issue with sending the email. Could you please provide more information or try again later?

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to john@test.com with subject 'Hello' and body 'How are you?'", additional_kwargs={}, response_metadata={}, id='99cf96dd-d326-4c53-a59c-01661a1ce27f'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 97, 'total_tokens': 125, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ff5f7093b3', 'id': 'chatcmpl-Co4H4lTtvNUCaAFZYfB8msZaiHrOh', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--dde7288c-16ea-41ef-8376-3e382a678e5b-0', tool_calls=[{'name': 'send_email_tool', 'args': {'recipient': 'john@test.com', 'subject': 'Hello', 'body': 'How are you?'}, 'id': 'call_Ja2ShKBMId9s2fin9JHbcZpc', 'type': 'tool_call'}], usage_metadata={'input_tokens': 97, 'output_tokens': 28, 'total_tokens': 125, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='User rejected the tool call for `send_email_tool` with id call_Ja2ShKBMId9s2fin9JHbcZpc', name='send_email_tool', id='0277e5e6-7c1b-472c-850b-8d94f2f3a070', tool_call_id='call_Ja2ShKBMId9s2fin9JHbcZpc', status='error'),
#   AIMessage(content='It seems there was an issue with sending the email. Could you please provide more information or try again later?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 165, 'total_tokens': 188, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ff5f7093b3', 'id': 'chatcmpl-Co4HQZqrz5FCfuShM6cXcdxpIzVsq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--1672c816-2f17-41f9-8dd0-d99112c8f72b-0', usage_metadata={'input_tokens': 165, 'output_tokens': 23, 'total_tokens': 188, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ### Editing

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langgraph.checkpoint.memory import InMemorySaver


def read_email_tool(email_id: str) -> str:
    """Mock function to read an email by its ID."""
    return f"Email content for ID: {email_id}"

def send_email_tool(recipient: str, subject: str, body: str) -> str:
    """Mock function to send an email."""
    return f"Email sent to {recipient} with subject '{subject}'"

agent = create_agent(
    model="gpt-4o",
    tools=[read_email_tool,send_email_tool],
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_email_tool": {
                    "allowed_decisions": ["approve", "edit", "reject"],
                },
                "read_email_tool": False,
            }
        ),
    ],
)

# %%
config = {"configurable": {"thread_id": "test-edit"}}

# Step 1: Request (with wrong info)
result = agent.invoke(
    {"messages": [HumanMessage(content="Send email to wrong@email.com with subject 'Test' and body 'Hello'")]},
    config=config
)

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to wrong@email.com with subject 'Test' and body 'Hello'", additional_kwargs={}, response_metadata={}, id='078c852f-cc67-4e0e-bee2-1e80e8d52598'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 95, 'total_tokens': 120, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ff5f7093b3', 'id': 'chatcmpl-Co4I843MzNcaHARohEYFcE1RGYiJy', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--16d13698-ce64-4c47-aa2d-d1074c4b9032-0', tool_calls=[{'name': 'send_email_tool', 'args': {'recipient': 'wrong@email.com', 'subject': 'Test', 'body': 'Hello'}, 'id': 'call_8bku3hoUOJqnnR2FUM2ZO61d', 'type': 'tool_call'}], usage_metadata={'input_tokens': 95, 'output_tokens': 25, 'total_tokens': 120, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'send_email_tool', 'args': {'recipient': 'wrong@email.com', 'subject': 'Test', 'body': 'Hello'}, 'description': "Tool execution requires approval\n\nTool: send_email_tool\nArgs: {'recipient': 'wrong@email.com', 'subject': 'Test', 'body': 'Hello'}"}], 'review_configs': [{'action_name': 'send_email_tool', 'allowed_decisions': ['approve', 'edit', 'reject']}]}, id='862f67a1ec885e2693c211d7fd7af91b')]}

# %%
# Step 2: Edit and approve
if "__interrupt__" in result:
    print("⏸️ Paused! Editing...")
    
    result = agent.invoke(
        Command(
            resume={
                "decisions": [
                    {
                        "type": "edit",
                        "edited_action": {
                            "name": "send_email_tool",      # Tool name
                            "args": {                   # New arguments
                                "recipient": "correct@email.com",
                                "subject": "Corrected Subject",
                                "body": "This was edited by human before sending"
                            }
                        }
                    }
                ]
            }
        ),
        config=config
    )
    
    print(f"✏️ Result: {result['messages'][-1].content}")
# Out:
# ⏸️ Paused! Editing...
# ✏️ Result: The email has been successfully sent.

# %%
result
# Out:
# {'messages': [HumanMessage(content="Send email to wrong@email.com with subject 'Test' and body 'Hello'", additional_kwargs={}, response_metadata={}, id='078c852f-cc67-4e0e-bee2-1e80e8d52598'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 95, 'total_tokens': 120, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ff5f7093b3', 'id': 'chatcmpl-Co4I843MzNcaHARohEYFcE1RGYiJy', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--16d13698-ce64-4c47-aa2d-d1074c4b9032-0', tool_calls=[{'type': 'tool_call', 'name': 'send_email_tool', 'args': {'recipient': 'correct@email.com', 'subject': 'Corrected Subject', 'body': 'This was edited by human before sending'}, 'id': 'call_8bku3hoUOJqnnR2FUM2ZO61d'}], usage_metadata={'input_tokens': 95, 'output_tokens': 25, 'total_tokens': 120, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="Email sent to correct@email.com with subject 'Corrected Subject'", name='send_email_tool', id='a34fd6aa-2863-4a58-b475-498bbfac91cc', tool_call_id='call_8bku3hoUOJqnnR2FUM2ZO61d'),
#   AIMessage(content='The email has been successfully sent.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 150, 'total_tokens': 158, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ff5f7093b3', 'id': 'chatcmpl-Co4IiKWItghiL4mc6RBGoXeNZ6ZSM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--be785473-610b-4960-bfa6-aa0e25451865-0', usage_metadata={'input_tokens': 150, 'output_tokens': 8, 'total_tokens': 158, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
