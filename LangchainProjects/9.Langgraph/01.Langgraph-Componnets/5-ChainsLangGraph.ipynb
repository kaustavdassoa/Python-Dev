# %% [markdown]
# ### Chain Using LangGraph
# In this section we will see how we can build a simple chain using Langgraph that uses 4 important concepts
#
# - How to use chat messages as our graph state
# - How to use chat models in graph nodes
# - How to bind tools to our LLM in chat models
# - How to execute the tools call in our graph nodes

# %%
from dotenv import load_dotenv
load_dotenv()

import os
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %% [markdown]
# #### How to use chat messages as our graph state
# ##### Messages
#
# We can use messages which can be used to capture different roles within a conversation.
# LangChain has various message types including HumanMessage, AIMessage, SystemMessage and ToolMessage.
# These represent a message from the user, from chat model, for the chat model to instruct behavior, and from a tool call.
#
# Every message have these important components.
#
# - content - content of the message
# - name - Specify the name of author
# - response_metadata - optionally, a dict of metadata (e.g., often populated by model provider for AIMessages)

# %%
from langchain_core.messages import AIMessage,HumanMessage
from pprint import pprint

messages=[AIMessage(content=f"Please tell me how can I help",name="LLMModel")]
messages.append(HumanMessage(content=f"I want to learn coding",name="Krish"))
messages.append(AIMessage(content=f"Which programming language you want to learn",name="LLMModel"))
messages.append(HumanMessage(content=f"I want to learn python programming language",name="Krish"))

for message in messages:
    message.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: LLMModel
#
# Please tell me how can I help
# ================================ Human Message =================================
# Name: Krish
#
# I want to learn coding
# ================================== Ai Message ==================================
# Name: LLMModel
#
# Which programming language you want to learn
# ================================ Human Message =================================
# Name: Krish
#
# I want to learn python programming language

# %% [markdown]
# ### Chat Models
#
# We can use the sequence of message as input with the chatmodels using LLM's and OPENAI.

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(model="qwen/qwen3-32b")
result=llm.invoke(messages)

# %%
print(f"{result.response_metadata}")
print(f"{result.content}")
# Out:
# {'token_usage': {'completion_tokens': 1600, 'prompt_tokens': 54, 'total_tokens': 1654, 'completion_time': 7.814528625, 'completion_tokens_details': None, 'prompt_time': 0.005902643, 'prompt_tokens_details': None, 'queue_time': 0.159555527, 'total_time': 7.820431268}, 'model_name': 'qwen/qwen3-32b', 'system_fingerprint': 'fp_2bfcc54d36', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}
# <think>
# Okay, the user wants to learn Python. Let me start by breaking down the steps they need to take. First, they'll need to install Python. I should mention the official website and maybe the latest version. Then an IDE, like VS Code or PyCharm. I should explain why an IDE is useful.
#
# Next, basics: syntax, variables, data types. Maybe start with print statements and comments. Then move on to control structures like loops and conditionals. Functions and data structures like lists and dictionaries are fundamental. Modules and libraries are important too, maybe mention some common ones like requests or numpy.
#
# Projects are a good way to apply what they've learned. Suggesting small projects like a calculator or a to-do list could help. Also, online resources like Codecademy or freeCodeCamp might be helpful. Practice is key, so they should code every day. Debugging is part of the process, so I should encourage them not to get discouraged by errors.
#
# Community support is also important. Maybe mention GitHub for collaboration and Stack Overflow for troubleshooting. Advanced topics like object-oriented programming and web development with Flask or Django can come later. Finally, staying motivated with small goals and tracking progress. Let me make sure the steps are clear and ordered from beginner to advanced. Avoid jargon where possible and keep it encouraging.
# </think>
#
# Learning Python is a fantastic choice! 🐍 Here’s a structured roadmap to help you start your Python journey, step by step:
#
# ---
#
# ### **1. Set Up Your Environment**
# - **Install Python**:
#   Download the latest version from [python.org](https://www.python.org/).
#   - During installation, **check the box** to add Python to your system’s PATH (Windows) or ensure it’s installed correctly (Mac/Linux).
# - **Choose a Code Editor/IDE**:
#   - **Beginners**: Use **VS Code** (free, lightweight) with the Python extension or **PyCharm Community Edition** (free for Python).
#   - **Alternative**: Jupyter Notebook for interactive coding (great for data science).
#
# ---
#
# ### **2. Learn the Basics (First 1–2 Weeks)**
# Start with foundational concepts:
# - **Syntax and Structure**:
#   - Write your first program:
#     ```python
#     print("Hello, World!")
#     ```
#   - Comments: Use `#` for single-line comments.
# - **Variables and Data Types**:
#   - Integers, floats, strings, booleans, and type conversion.
#     ```python
#     age = 25
#     name = "Alice"
#     is_student = True
#     ```
# - **Basic Operations**:
#   - Arithmetic (`+`, `-`, `*`, `/`), string concatenation.
# - **Input and Output**:
#   - `input()` function to get user input.
#
# ---
#
# ### **3. Control Flow (Week 2–3)**
# - **Conditionals**:
#   ```python
#   if age >= 18:
#       print("You're an adult.")
#   elif age >= 13:
#       print("You're a teenager.")
#   else:
#       print("You're a child.")
#   ```
# - **Loops**:
#   - `for` loops (e.g., iterate over lists):
#     ```python
#     for i in range(5):
#         print(i)
#     ```
#   - `while` loops for repeated actions.
#
# ---
#
# ### **4. Functions and Data Structures (Week 3–4)**
# - **Functions**:
#   ```python
#   def greet(name):
#       print(f"Hello, {name}!")
#   ```
# - **Data Structures**:
#   - **Lists**: `fruits = ["apple", "banana"]`
#   - **Tuples**: `coordinates = (10, 20)`
#   - **Dictionaries**: `person = {"name": "Alice", "age": 25}`
#   - **Sets**: `unique_numbers = {1, 2, 3}`
#
# ---
#
# ### **5. File Handling and Error Handling**
# - **Read/Write Files**:
#   ```python
#   with open("file.txt", "r") as file:
#       content = file.read()
#   ```
# - **Error Handling**:
#   ```python
#   try:
#       result = 10 / 0
#   except ZeroDivisionError:
#       print("Cannot divide by zero!")
#   ```
#
# ---
#
# ### **6. Modules and External Libraries**
# - Use built-in modules like `math`, `random`, or `datetime`.
# - Install external libraries via **pip**:
#   ```bash
#   pip install requests  # For HTTP requests
#   pip install numpy     # For numerical computations
#   ```
# - Example with `requests`:
#   ```python
#   import requests
#   response = requests.get("https://api.github.com")
#   print(response.status_code)
#   ```
#
# ---
#
# ### **7. Practice Projects (Start After Week 4)**
# **Beginner Projects**:
# - Calculator
# - To-Do List (CLI)
# - Number Guessing Game
#
# **Intermediate Projects**:
# - Weather App using an API (e.g., [OpenWeatherMap](https://openweathermap.org/api))
# - Web Scraper with `BeautifulSoup`
# - Simple Chatbot
#
# **Advanced Projects**:
# - Build a web app with **Flask** or **Django**
# - Data analysis with **Pandas** and **Matplotlib**
#
# ---
#
# ### **8. Learn from Free Resources**
# - **Interactive Tutorials**:
#   - [Codecademy Python Course](https://www.codecademy.com/learn/learn-python)
#   - [freeCodeCamp Python Guide](https://www.freecodecamp.org/news/learn-python/)
# - **YouTube Channels**:
#   - [Corey Schafer](https://www.youtube.com/c/CoreySchafer) (advanced topics)
#   - [Tech With Tim](https://www.youtube.com/c/TechWithTim) (beginner-friendly)
# - **Books**:
#   - *"Python Crash Course"* by Eric Matthes
#   - *"Automate the Boring Stuff with Python"* by Al Sweigart
#
# ---
#
# ### **9. Practice Daily**
# - Solve coding challenges on platforms like:
#   - [LeetCode](https://leetcode.com/) (filter Python problems)
#   - [HackerRank](https://hackerrank.com/domains/python)
# - Build small projects daily (e.g., a text-based quiz or a BMI calculator).
#
# ---
#
# ### **10. Join the Community**
# - **Forums**:
#   - [Stack Overflow](https://stackoverflow.com/) (ask questions)
#   - [Reddit r/learnpython](https://www.reddit.com/r/learnpython/)
# - **GitHub**: Share your projects, collaborate, and learn from others.
#
# ---
#
# ### **11. Advanced Topics (After Mastery)**
# - **Object-Oriented Programming (OOP)**: Classes and objects.
# - **Web Development**: Flask/Django for websites.
# - **Data Science/Machine Learning**:
#   - Libraries: `numpy`, `pandas`, `scikit-learn`, `TensorFlow`
# - **Automation**: Use Python for scripting repetitive tasks.
#
# ---
#
# ### **Key Tips**
# - **Debugging**: Learn to read error messages. Use `print()` or a debugger.
# - **Patience**: Errors are part of learning. Google is your friend!
# - **Documentation**: Always refer to the [official Python docs](https://docs.python.org/3/).
#
# Let me know if you want a **starter project idea**, **code examples**, or help with **specific topics**! 😊

# %% [markdown]
# ### Tools
# Tools can be integrated with the LLM models to interact with external systems. External systems can be API's, third party tools.
#
# Whenever a query is asked the model can choose to call the tool and this query is based on the
# natural language input and this will return an output that matches the tool's schema

# %%
def add(a:int,b:int)-> int:
    """ Add a and b
    Args:
        a (int): first int
        b (int): second int

    Returns:
        int
    """
    return a+b

# %%
llm
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 16384, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x0000021B4167A600>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000021B5D8066F0>, model_name='qwen/qwen3-32b', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
### Binding tool with llm

llm_with_tools=llm.bind_tools([add])

tool_call=llm_with_tools.invoke([HumanMessage(content=f"What is 2 plus 2",name="Krish")])

# %%
tool_call.tool_calls
# Out:
# [{'name': 'add',
#   'args': {'a': 2, 'b': 2},
#   'id': 'call_bxje',
#   'type': 'tool_call'}]

# %% [markdown]
# ### Using messages as state

# %%
from typing_extensions import TypedDict
from langchain_core.messages import AnyMessage

class State(TypedDict):
    message:list[AnyMessage]

# %% [markdown]
# #### Reducers
# Now, we have a minor problem!
#
# As we discussed, each node will return a new value for our state key messages.
#
# But, this new value will override the prior messages value.
#
# As our graph runs, we want to append messages to our messages state key.
#
# We can use reducer functions to address this.
#
# Reducers allow us to specify how state updates are performed.
#
# If no reducer function is specified, then it is assumed that updates to the key should override it as we saw before.
#
# But, to append messages, we can use the pre-built add_messages reducer.
#
# This ensures that any messages are appended to the existing list of messages.
#
# We simply need to annotate our messages key with the add_messages reducer function as metadata.

# %%
from langgraph.graph.message import add_messages
from typing import Annotated
class State(TypedDict):
    messages:Annotated[list[AnyMessage],add_messages]

# %% [markdown]
# ### Reducers with add_messages

# %%
initial_messages=[AIMessage(content=f"Please tell me how can I help",name="LLMModel")]
initial_messages.append(HumanMessage(content=f"I want to learn coding",name="Krish"))
initial_messages
# Out:
# [AIMessage(content='Please tell me how can I help', additional_kwargs={}, response_metadata={}, name='LLMModel'),
#  HumanMessage(content='I want to learn coding', additional_kwargs={}, response_metadata={}, name='Krish')]

# %%
ai_message=AIMessage(content=f"Which programming language you want to learn",name="LLMModel")
ai_message
# Out:
# AIMessage(content='Which programming language you want to learn', additional_kwargs={}, response_metadata={}, name='LLMModel')

# %%
### Reducers add_messages is to append instead of override
add_messages(initial_messages,ai_message)
# Out:
# [AIMessage(content='Please tell me how can I help', additional_kwargs={}, response_metadata={}, name='LLMModel', id='4572805c-1f92-451f-8e30-4420e17ada31'),
#  HumanMessage(content='I want to learn coding', additional_kwargs={}, response_metadata={}, name='Krish', id='3542ff9a-787f-49c4-a744-e8259a0e1636'),
#  AIMessage(content='Which programming language you want to learn', additional_kwargs={}, response_metadata={}, name='LLMModel', id='d5dc00a9-9cac-4b13-85fe-1b823e62b851')]

# %%
## chatbot node functionality
def llm_tool(state:State):
    return {"messages":[llm_with_tools.invoke(state["messages"])]}

# %%
from IPython.display import Image, display
from langgraph.graph import StateGraph, START, END
builder=StateGraph(State)

builder.add_node("llm_tool",llm_tool)

builder.add_edge(START,"llm_tool")
builder.add_edge("llm_tool",END)

graph=builder.compile()

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
## invocation

messages=graph.invoke({"messages":"What is 2 plus 2"})

for message in messages["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is 2 plus 2
# ================================== Ai Message ==================================
# Tool Calls:
#   add (cdgf12f8k)
#  Call ID: cdgf12f8k
#   Args:
#     a: 2
#     b: 2

# %%
tools=[add]

# %%
from langgraph.prebuilt import ToolNode
from langgraph.prebuilt import tools_condition


builder=StateGraph(State)

## Add nodes

builder.add_node("llm_tool",llm_tool)
builder.add_node("tools",ToolNode(tools))

## Add Edge
builder.add_edge(START,"llm_tool")
builder.add_conditional_edges(
    "llm_tool",
    # If the latest message (result) from assistant is a tool call -> tools_condition routes to tools
    # If the latest message (result) from assistant is a not a tool call -> tools_condition routes to END
    tools_condition
)
builder.add_edge("tools",END)


graph_builder = builder.compile()

# %%
display(Image(graph_builder.get_graph().draw_mermaid_png()))

# %%
## invocation

messages=graph.invoke({"messages":"What is 2 plus 2"})

for message in messages["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What is 2 plus 2
# ================================== Ai Message ==================================
# Tool Calls:
#   add (8jx1648jz)
#  Call ID: 8jx1648jz
#   Args:
#     a: 2
#     b: 2

# %%
messages=graph.invoke({"messages":"What Machine Learning"})

for message in messages["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# What Machine Learning
# ================================== Ai Message ==================================
#
# The function provided is for adding two integers, but your question is about machine learning. I don't have access to tools that can explain concepts or provide information. Would you like me to help with something else that can be addressed using the available function?
